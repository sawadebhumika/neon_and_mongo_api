# %%
import requests

url = "https://api.euron.one/api/v1/euri/images/generations"

payload = {
    "model": "black-forest-labs/FLUX.1-schnell",
    "prompt": "Generate  a beatiful image of the building landscape",
    "n": 2,
    "size": "1024x1024",
    "quality": "standard",
    "response_format": "url"
}
headers = {
    "Authorization": "Bearer eu*********************************************38",
    "Content-Type": "application/json"
}

response = requests.post(url, json=payload, headers=headers)

print(response.text)
# Out:
# {"created":1778943835,"data":[{"url":"https://euri-user-files.s3.ap-south-1.amazonaws.com/generated-images/825b64fe-c9f4-40bd-94ce-32e5822dc477/294d9565-0f1b-4599-a6be-20cadfd07bec.png","revised_prompt":"Generate  qa beatiful image of the building landscape"},{"url":"https://euri-user-files.s3.ap-south-1.amazonaws.com/generated-images/825b64fe-c9f4-40bd-94ce-32e5822dc477/33eb88f7-8376-48aa-874a-8d4a3849d423.png","revised_prompt":"Generate  qa beatiful image of the building landscape"}]}
